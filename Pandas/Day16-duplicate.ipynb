# %%
import pandas as pd

# %%
dt=pd.read_excel(r"C:\Users\hi\Documents\Desktop\Minskole classes\Pandas\inputData.xlsx")
dt
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
dt1=dt.copy()

# %%
dt1
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
dt1['Total']=dt1['English']+dt1['Physics']+dt1['Chemistry']+dt1['Mathematics']

# %%
dt1
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total
# 0       Aarav     Patil       85       78         90           92    345
# 1      Vihaan  Deshmukh       88       81         85           89    343
# 2       Ayaan    Jadhav       90       75         88           84    337
# 3       Arjun      More       76       89         91           78    334
# 4     Reyansh     Joshi       82       80         84           85    331
# ..        ...       ...      ...      ...        ...          ...    ...
# 60      Tarun    Dhumal       82       87         81           85    335
# 61      Arnav   Khedkar       85       90         78           89    342
# 62      Payal     Patil       89       76         87           91    343
# 63      Rahul     Kadam       81       83         84           90    338
# 64        Jay    Bhagat       90       77         65           88    320
#
# [65 rows x 7 columns]

# %%
dt1['Full Name']=dt1['First Name']+" "+dt1['Last Name']
dt1
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 0       Aarav     Patil       85       78         90           92    345
# 1      Vihaan  Deshmukh       88       81         85           89    343
# 2       Ayaan    Jadhav       90       75         88           84    337
# 3       Arjun      More       76       89         91           78    334
# 4     Reyansh     Joshi       82       80         84           85    331
# ..        ...       ...      ...      ...        ...          ...    ...
# 60      Tarun    Dhumal       82       87         81           85    335
# 61      Arnav   Khedkar       85       90         78           89    342
# 62      Payal     Patil       89       76         87           91    343
# 63      Rahul     Kadam       81       83         84           90    338
# 64        Jay    Bhagat       90       77         65           88    320
#
#           Full Name
# 0       Aarav Patil
# 1   Vihaan Deshmukh
# 2      Ayaan Jadhav
# ...

# %%
dt
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
# Sorts the DataFrame by the specified column(s):
# Syntax:
# sort_values(by, ascending=True/False, inplace=True/False): 
#                     True                False              ==> default 

# inplace : True==> Change in original dataframe
#          False==> Changes not visible in original dataframe

# %%
dt1.sort_values(by='Last Name')
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 64        Jay       Bhagat       90       77         65           88    320
# 41       Jaya       Bhagat       92       88         76           89    345
# 56      Aarvi     Bhandari       90       81         85           91    347
# 33      Aarvi     Bhandari       90       81         85           91    347
# 8       Krish      Bhosale       80       85         83           89    337
# ..        ...          ...      ...      ...        ...          ...    ...
# 9     Samarth       Shinde       89       79         87           88    343
# 17      Rohan  Suryavanshi       78       82         90           86    336
# 7       Rohan  Suryavanshi       78       82         90           86    336
# 24      Tejas     Waghmare       85       82         90           85    342
# 47      Tejas     Waghmare       85       82         90           85    342
#
#             Full Name
# 64         Jay Bhagat
# ...

# %%
dt2=dt1.sort_values(by='Total',ascending=False)
dt2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 58      Sneha   Gokhale       88       84         90           86    348
# 35      Sneha   Gokhale       88       84         90           86    348
# 33      Aarvi  Bhandari       90       81         85           91    347
# 6      Aditya     Pawar       92       88         76           91    347
# 16     Aditya     Pawar       92       88         76           91    347
# ..        ...       ...      ...      ...        ...          ...    ...
# 4     Reyansh     Joshi       82       80         84           85    331
# 14    Reyansh     Joshi       82       80         84           85    331
# 27      Tanvi    Ingale       78       77         83           92    330
# 50      Tanvi    Ingale       78       77         83           92    330
# 64        Jay    Bhagat       90       77         65           88    320
#
#          Full Name
# 58   Sneha Gokhale
# 35   Sneha Gokhale
# 33  Aarvi Bhandari
# ...

# %%
dt1
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 58      Sneha   Gokhale       88       84         90           86    348
# 35      Sneha   Gokhale       88       84         90           86    348
# 33      Aarvi  Bhandari       90       81         85           91    347
# 6      Aditya     Pawar       92       88         76           91    347
# 16     Aditya     Pawar       92       88         76           91    347
# ..        ...       ...      ...      ...        ...          ...    ...
# 4     Reyansh     Joshi       82       80         84           85    331
# 14    Reyansh     Joshi       82       80         84           85    331
# 27      Tanvi    Ingale       78       77         83           92    330
# 50      Tanvi    Ingale       78       77         83           92    330
# 64        Jay    Bhagat       90       77         65           88    320
#
#          Full Name
# 58   Sneha Gokhale
# 35   Sneha Gokhale
# 33  Aarvi Bhandari
# ...

# %%
# inplace : True==> Change in original dataframe
# False==> Changes not visible in original dataframe

# %%
dt3=dt1.sort_values(by='Full Name',ascending=False,inplace=False)
dt3
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 5      Vivaan      Nair       87       83         79           90    339
# 15     Vivaan      Nair       87       83         79           90    339
# 1      Vihaan  Deshmukh       88       81         85           89    343
# 11     Vihaan  Deshmukh       88       81         85           89    343
# 24      Tejas  Waghmare       85       82         90           85    342
# ..        ...       ...      ...      ...        ...          ...    ...
# 30      Aditi    Rajput       90       88         82           87    347
# 56      Aarvi  Bhandari       90       81         85           91    347
# 33      Aarvi  Bhandari       90       81         85           91    347
# 0       Aarav     Patil       85       78         90           92    345
# 10      Aarav     Patil       85       78         90           92    345
#
#           Full Name
# 5       Vivaan Nair
# 15      Vivaan Nair
# 1   Vihaan Deshmukh
# ...

# %%
dt1
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 58      Sneha   Gokhale       88       84         90           86    348
# 35      Sneha   Gokhale       88       84         90           86    348
# 33      Aarvi  Bhandari       90       81         85           91    347
# 6      Aditya     Pawar       92       88         76           91    347
# 16     Aditya     Pawar       92       88         76           91    347
# ..        ...       ...      ...      ...        ...          ...    ...
# 4     Reyansh     Joshi       82       80         84           85    331
# 14    Reyansh     Joshi       82       80         84           85    331
# 27      Tanvi    Ingale       78       77         83           92    330
# 50      Tanvi    Ingale       78       77         83           92    330
# 64        Jay    Bhagat       90       77         65           88    320
#
#          Full Name
# 58   Sneha Gokhale
# 35   Sneha Gokhale
# 33  Aarvi Bhandari
# ...

# %%
dt1.columns
# Out:
# Index(['First Name', 'Last Name', 'English', 'Physics', 'Chemistry',
#        'Mathematics', 'Total', 'Full Name'],
#       dtype='object')

# %%
dt1.sort_values(by=['First Name','Total'],ascending=[True,False])
dt1
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 58      Sneha   Gokhale       88       84         90           86    348
# 35      Sneha   Gokhale       88       84         90           86    348
# 33      Aarvi  Bhandari       90       81         85           91    347
# 6      Aditya     Pawar       92       88         76           91    347
# 16     Aditya     Pawar       92       88         76           91    347
# ..        ...       ...      ...      ...        ...          ...    ...
# 4     Reyansh     Joshi       82       80         84           85    331
# 14    Reyansh     Joshi       82       80         84           85    331
# 27      Tanvi    Ingale       78       77         83           92    330
# 50      Tanvi    Ingale       78       77         83           92    330
# 64        Jay    Bhagat       90       77         65           88    320
#
#          Full Name
# 58   Sneha Gokhale
# 35   Sneha Gokhale
# 33  Aarvi Bhandari
# ...

# %% [markdown]
# #### Duplicate

# %%
dt1.shape
# Out:
# (65, 8)

# %%
dt1[dt1.duplicated()]
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 35      Sneha      Gokhale       88       84         90           86    348
# 16     Aditya        Pawar       92       88         76           91    347
# 56      Aarvi     Bhandari       90       81         85           91    347
# 53      Aditi       Rajput       90       88         82           87    347
# 10      Aarav        Patil       85       78         90           92    345
# 44      Anaya      Gawande       84       90         82           88    344
# 9     Samarth       Shinde       89       79         87           88    343
# 1      Vihaan     Deshmukh       88       81         85           89    343
# 39      Payal        Patil       89       76         87           91    343
# 59      Pooja       Mhatre       84       79         88           92    343
# 38      Arnav      Khedkar       85       90         78           89    342
# ...

# %%
dt1.drop_duplicates(inplace=True)

# %%
dt1
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  Total  \
# 58      Sneha      Gokhale       88       84         90           86    348
# 33      Aarvi     Bhandari       90       81         85           91    347
# 6      Aditya        Pawar       92       88         76           91    347
# 30      Aditi       Rajput       90       88         82           87    347
# 0       Aarav        Patil       85       78         90           92    345
# 41       Jaya       Bhagat       92       88         76           89    345
# 21      Anaya      Gawande       84       90         82           88    344
# 19    Samarth       Shinde       89       79         87           88    343
# 11     Vihaan     Deshmukh       88       81         85           89    343
# 36      Pooja       Mhatre       84       79         88           92    343
# 62      Payal        Patil       89       76         87           91    343
# ...

# %%
dt1.shape
# Out:
# (34, 8)

# %%
dt[dt['First Name']=='Rahul']
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 40      Rahul     Kadam       81       83         84           90
# 63      Rahul     Kadam       81       83         84           90
