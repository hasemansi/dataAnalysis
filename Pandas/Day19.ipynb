# %%
import pandas as pd

# %%
# # Rename 
# # Syntax
# 1)Row labelled
#  dataframe_name.rename(index         = {1:"One",               4:"Four"} , inplace= True/False)
#                        For Row         Old value : New value,

# 2)Columns labelled
#  dataframe_name.rename(columns         = {1:"One",               4:"Four"} , inplace= True/False)
#                        For Column         Old value : New value,

# %%
# # Drop 
# # Syntax
# # 1) Drop record (row)
# dataframe_name.drop([row_index], inplace= True/False) # By default axis=0

# # 2) Drop column
# dataframe_name.drop([column_name], axis=1, inplace= True/False)

# %%
# Change column datatype /Typecasting
# Syntax
# dataframe/column.astype(new_datatype)

# %%
# Export data to excel/csv
#1) Excel file: 
#               DataFrame_name.to_excel(r"path/filename.xlsx",index=False/True)
#2) CSV file: 
#               DataFrame_name.to_csv(r"path/filename.csv",index=False/True)

# %%
# Load "Input data2"
data=pd.read_excel(r"E:\Minskole Batch\Python Batch\Input data2.xlsx")

# %%
data.head(2)
# Out:
#   First Name Last Name English Physics Chemistry Mathematics
# 1      Aarav     Patil      85      78        90          92
# 2     Vihaan  Deshmukh      88      81        85          89

# %%
data.drop(0,inplace=True) # axis=0

# %%
data.head(2)
# Out:
#   First Name Last Name English Physics Chemistry Mathematics
# 1      Aarav     Patil      85      78        90          92
# 2     Vihaan  Deshmukh      88      81        85          89

# %%
# Add "Name" column ( Combination of "First Name" and "Last Name")
data["Name"] = data["First Name"] +" "+ data["Last Name"]

# %%
data.head(2)
# Out:
#   First Name Last Name English Physics Chemistry Mathematics        Full Name
# 1      Aarav     Patil      85      78        90          92      Aarav Patil
# 2     Vihaan  Deshmukh      88      81        85          89  Vihaan Deshmukh

# %%
# Change column name from "Name" to "Full Name"
data.rename(columns={#key : value
                      # old value  : New Value
                      "Name" : "Full Name"},inplace=True)

# %%
data.head(2)
# Out:
#   First Name Last Name English Physics Chemistry Mathematics        Full Name
# 1      Aarav     Patil      85      78        90          92      Aarav Patil
# 2     Vihaan  Deshmukh      88      81        85          89  Vihaan Deshmukh

# %%
data.columns
# Out:
# Index(['First Name', 'Last Name', 'English', 'Physics', 'Chemistry',
#        'Mathematics', 'Full Name'],
#       dtype='object')

# %%
data2 = data.copy()

# %%
data2.head(2)
# Out:
#          Full Name First Name Last Name English Physics Chemistry Mathematics
# 1      Aarav Patil      Aarav     Patil      85      78        90          92
# 2  Vihaan Deshmukh     Vihaan  Deshmukh      88      81        85          89

# %%
# Delete not required columns (First Name" and "Last Name")

# %%
data.drop(["First Name","Last Name"],axis=1,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13652\2910314983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(["First Name","Last Name"],axis=1,inplace=True)

# %%
data
# Out:
#           Full Name English Physics Chemistry Mathematics
# 1       Aarav Patil      85      78        90          92
# 2   Vihaan Deshmukh      88      81        85          89
# 3      Ayaan Jadhav      90      75        88          84
# 4        Arjun More      76      89        91          78
# 5     Reyansh Joshi      82      80        84          85
# ..              ...     ...     ...       ...         ...
# 61     Tarun Dhumal      82      87        81          85
# 62    Arnav Khedkar      85      90        78          89
# 63      Payal Patil      89      76        87          91
# 64      Rahul Kadam      81      83        84          90
# 65       Jay Bhagat      90      77        65          88
#
# [65 rows x 5 columns]

# %%
# Change sequence of columns

# %%
data2 = data2[['Full Name', 'English', 'Physics', 'Chemistry',
       'Mathematics']]

# %%
data2
# Out:
#           Full Name English Physics Chemistry Mathematics
# 1       Aarav Patil      85      78        90          92
# 2   Vihaan Deshmukh      88      81        85          89
# 3      Ayaan Jadhav      90      75        88          84
# 4        Arjun More      76      89        91          78
# 5     Reyansh Joshi      82      80        84          85
# ..              ...     ...     ...       ...         ...
# 61     Tarun Dhumal      82      87        81          85
# 62    Arnav Khedkar      85      90        78          89
# 63      Payal Patil      89      76        87          91
# 64      Rahul Kadam      81      83        84          90
# 65       Jay Bhagat      90      77        65          88
#
# [65 rows x 5 columns]

# %%
# Check there is any duplicate records if yes then delete those
# See duplicate record
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Full Name, English, Physics, Chemistry, Mathematics]
# Index: []

# %%
# Delete duplicate records
data.drop_duplicates(inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13652\188478926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace=True)

# %%
data.head(2)
# Out:
#          Full Name English Physics Chemistry Mathematics
# 1      Aarav Patil      85      78        90          92
# 2  Vihaan Deshmukh      88      81        85          89

# %%
# Add "Total Marks" column

# %%
data["Total Marks"] = data["English"]+data["Physics"]+data["Chemistry"]+data["Mathematics"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13652\567487594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Total Marks"] = data["English"]+data["Physics"]+data["Chemistry"]+data["Mathematics"]

# %%
# Check datatype
data.dtypes
# Out:
# Full Name      object
# English        object
# Physics        object
# Chemistry      object
# Mathematics    object
# Total Marks    object
# dtype: object

# %%
data
# Out:
#             Full Name English Physics Chemistry Mathematics Total Marks
# 1         Aarav Patil      85      78        90          92    85789092
# 2     Vihaan Deshmukh      88      81        85          89         343
# 3        Ayaan Jadhav      90      75        88          84         337
# 4          Arjun More      76      89        91          78         334
# 5       Reyansh Joshi      82      80        84          85         331
# 6         Vivaan Nair      87      83        79          90         339
# 7        Aditya Pawar      92      88        76          91         347
# 8   Rohan Suryavanshi      78      82        90          86         336
# 9       Krish Bhosale      80      85        83          89         337
# 10     Samarth Shinde      89      79        87          88         343
# 11        Aarav Patil      85      78        90          92         345
# 21      Riya Kulkarni      91      84        78          87         340
# ...

# %%
# Export data

# %% [markdown]
# ### Change column datatype

# %%
# Change column datatype /Typecasting
# Syntax
# dataframe/column.astype(new_datatype)

# %%
data.dtypes
# Out:
# Full Name      object
# English        object
# Physics         int64
# Chemistry      object
# Mathematics    object
# Total Marks    object
# dtype: object

# %%
data["Physics"].dtype
# Out:
# dtype('int64')

# %%
data["Physics"] = data["Physics"].astype("int")

# %%
data["English"] = data["English"].astype("int")

# %%
data["Chemistry"] = data["Chemistry"].astype("int")

# %%
data["Mathematics"] = data["Mathematics"].astype("int")

# %%
data.columns
# Out:
# Index(['Full Name', 'English', 'Physics', 'Chemistry', 'Mathematics',
#        'Total Marks'],
#       dtype='object')

# %%
# Ignore/Hide warnings
import warnings
warnings.filterwarnings("ignore")

# %%
data.head()
# Out:
#          Full Name  English  Physics  Chemistry  Mathematics  Total Marks
# 1      Aarav Patil       85       78         90           92          345
# 2  Vihaan Deshmukh       88       81         85           89          343
# 3     Ayaan Jadhav       90       75         88           84          337
# 4       Arjun More       76       89         91           78          334
# 5    Reyansh Joshi       82       80         84           85          331

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 1 to 65
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Full Name    35 non-null     object
#  1   English      35 non-null     int64
#  2   Physics      35 non-null     int64
#  3   Chemistry    35 non-null     int64
#  4   Mathematics  35 non-null     int64
#  5   Total Marks  35 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.9+ KB

# %%
data
# Out:
#             Full Name  English  Physics  Chemistry  Mathematics Total Marks
# 1         Aarav Patil       85       78         90           92    85789092
# 2     Vihaan Deshmukh       88       81         85           89         343
# 3        Ayaan Jadhav       90       75         88           84         337
# 4          Arjun More       76       89         91           78         334
# 5       Reyansh Joshi       82       80         84           85         331
# 6         Vivaan Nair       87       83         79           90         339
# 7        Aditya Pawar       92       88         76           91         347
# 8   Rohan Suryavanshi       78       82         90           86         336
# 9       Krish Bhosale       80       85         83           89         337
# 10     Samarth Shinde       89       79         87           88         343
# 11        Aarav Patil       85       78         90           92         345
# ...

# %%
data["Total Marks"]=data['English']+data[ 'Physics']+data[ 'Chemistry']+data['Mathematics']

# %%
data
# Out:
#             Full Name  English  Physics  Chemistry  Mathematics  Total Marks
# 1         Aarav Patil       85       78         90           92          345
# 2     Vihaan Deshmukh       88       81         85           89          343
# 3        Ayaan Jadhav       90       75         88           84          337
# 4          Arjun More       76       89         91           78          334
# 5       Reyansh Joshi       82       80         84           85          331
# 6         Vivaan Nair       87       83         79           90          339
# 7        Aditya Pawar       92       88         76           91          347
# 8   Rohan Suryavanshi       78       82         90           86          336
# 9       Krish Bhosale       80       85         83           89          337
# 10     Samarth Shinde       89       79         87           88          343
# 11        Aarav Patil       85       78         90           92          345
# ...

# %%
data["Percentage"]=(data["Total Marks"]/400)*100  # Recived marks/Total marks *100

# %%
data
# Out:
#             Full Name  English  Physics  Chemistry  Mathematics  Total Marks  \
# 1         Aarav Patil       85       78         90           92          345
# 2     Vihaan Deshmukh       88       81         85           89          343
# 3        Ayaan Jadhav       90       75         88           84          337
# 4          Arjun More       76       89         91           78          334
# 5       Reyansh Joshi       82       80         84           85          331
# 6         Vivaan Nair       87       83         79           90          339
# 7        Aditya Pawar       92       88         76           91          347
# 8   Rohan Suryavanshi       78       82         90           86          336
# 9       Krish Bhosale       80       85         83           89          337
# 10     Samarth Shinde       89       79         87           88          343
# 11        Aarav Patil       85       78         90           92          345
# ...

# %%
data

# %%
data.to_excel(r"D:\Minskole Batch\Python\Export\Report.xlsx")

# %%
data.to_excel(r"D:\Minskole Batch\Python\Export\Report2.xlsx",index=False)

# %%
data.to_csv(r"D:\Minskole Batch\Python\Export\Report_csv.csv")

# %%
data.to_csv(r"D:\Minskole Batch\Python\Export\Report_csv2.csv",index=False)
