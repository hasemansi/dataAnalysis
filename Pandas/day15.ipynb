# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\hi\Documents\Desktop\Minskole classes\Pandas\foodhub_order.csv")
data
# Out:
#       order_id  customer id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %%
data.columns
# Out:
# Index(['order_id', 'customer id', 'restaurant_name', 'cuisine_type',
#        'cost_of_the_order', 'day_of_the_week', 'rating',
#        'food_preparation_time', 'delivery_time'],
#       dtype='object')

# %%
data.order_id
# Out:
# 0       1477147
# 1       1477685
# 2       1477070
# 3       1477334
# 4       1478249
#          ...
# 1893    1476701
# 1894    1477421
# 1895    1477819
# 1896    1477513
# 1897    1478056
# Name: order_id, Length: 1898, dtype: int64

# %%
data.customer id # this is not possible using .
# Out:
#   Cell In[6], line 1
#     data.customer id
#                   ^
# SyntaxError: invalid syntax

# %%
# using []
data['customer id']
# Out:
# 0       337525
# 1       358141
# 2        66393
# 3       106968
# 4        76942
#          ...
# 1893    292602
# 1894    397537
# 1895     35309
# 1896     64151
# 1897    120353
# Name: customer id, Length: 1898, dtype: int64

# %%
# accessing multiple columns 
data[['order_id','customer id','rating']]
# Out:
#       order_id  customer id     rating
# 0      1477147       337525  Not given
# 1      1477685       358141  Not given
# 2      1477070        66393          5
# 3      1477334       106968          3
# 4      1478249        76942          4
# ...        ...          ...        ...
# 1893   1476701       292602          5
# 1894   1477421       397537          5
# 1895   1477819        35309  Not given
# 1896   1477513        64151          5
# 1897   1478056       120353  Not given
#
# [1898 rows x 3 columns]

# %%
data
# Out:
#       order_id  customer id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %%
# add new column
data['order_completion_time']=data['food_preparation_time']+data['delivery_time']

# %%
data
# Out:
#       order_id  customer id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %%
data['order status']='complete'
data
# Out:
#       order_id  customer id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# ...

# %%
dt=pd.read_excel(r"C:\Users\hi\Documents\Desktop\Minskole classes\Pandas\inputData.xlsx")
dt
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
dt.size
# Out:
# 390

# %%
dt['First Name']=='Aarav'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Name: First Name, Length: 65, dtype: bool

# %%
dt[dt['First Name']=='Aarav']
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 10      Aarav     Patil       85       78         90           92

# %%
# Filter data : Students secured greater than 80 marks in Physics
dt[dt['Physics']>80]
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics
# 1      Vihaan     Deshmukh       88       81         85           89
# 3       Arjun         More       76       89         91           78
# 5      Vivaan         Nair       87       83         79           90
# 6      Aditya        Pawar       92       88         76           91
# 7       Rohan  Suryavanshi       78       82         90           86
# 8       Krish      Bhosale       80       85         83           89
# 11     Vihaan     Deshmukh       88       81         85           89
# 13      Arjun         More       76       89         91           78
# 15     Vivaan         Nair       87       83         79           90
# 16     Aditya        Pawar       92       88         76           91
# 17      Rohan  Suryavanshi       78       82         90           86
# 18      Krish      Bhosale       80       85         83           89
# 20       Riya     Kulkarni       91       84         78           87
# ...

# %%
# Filter data : Students name is "Samarth"
dt[dt['First Name']=='Samarth']
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 9     Samarth    Shinde       89       79         87           88
# 19    Samarth    Shinde       89       79         87           88

# %%
# Filter records whoes First name is Arjun and Tarun using operator
dt[(dt['First Name']=='Arjun') | (dt['First Name']=='Tarun')]
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 3       Arjun      More       76       89         91           78
# 13      Arjun      More       76       89         91           78
# 37      Tarun    Dhumal       82       87         81           85
# 60      Tarun    Dhumal       82       87         81           85

# %%
# Filter records whoes First name is Arjun and Tarun using isin
dt[dt['First Name'].isin(['Arjun','Tarun'])]
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 3       Arjun      More       76       89         91           78
# 13      Arjun      More       76       89         91           78
# 37      Tarun    Dhumal       82       87         81           85
# 60      Tarun    Dhumal       82       87         81           85

# %%
# First name except Arjun and Tarun
dt[~dt['First Name'].isin(['Arjun','Tarun'])]
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 4     Reyansh     Joshi       82       80         84           85
# 5      Vivaan      Nair       87       83         79           90
# ..        ...       ...      ...      ...        ...          ...
# 59      Pooja    Mhatre       84       79         88           92
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [61 rows x 6 columns]

# %%
# Copy
# 1) Shallow Copy:Just creates a reference; changes in copy will affect original df.
#     df_copy = df.copy(deep=False)
# 2) Deep Copy: Creates an independent copy, so changes in copy won’t affect original df.
#     df_copy = df.copy(deep=True) 
#     df_copy = df.copy()   #by default = True

# %%
dt2=dt

# %%
dt2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
dt3=dt.copy(deep=False)
dt3
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
dt3=dt.copy()
dt3
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
dt3.head(3)
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89
# 2      Ayaan    Jadhav       90       75         88           84
