# %%
import numpy as np

# %% [markdown]
# ### Mathematical Function

# %%
b=np.arange(2,41,2).reshape((5,4),order="F")
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
b.sum()
# Out:
# np.int64(420)

# %%
b.sum(axis=0) # summation by column
# Out:
# array([ 30,  80, 130, 180])

# %%
b.sum(axis=1) # summation by row
# Out:
# array([ 68,  76,  84,  92, 100])

# %% [markdown]
# #### Cumulative Sum

# %%
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
b.cumsum()
# Out:
# array([  2,  14,  36,  68,  72,  86, 110, 144, 150, 166, 192, 228, 236,
#        254, 282, 320, 330, 350, 380, 420])

# %%
b.cumsum(axis=0)
# Out:
# array([[  2,  12,  22,  32],
#        [  6,  26,  46,  66],
#        [ 12,  42,  72, 102],
#        [ 20,  60, 100, 140],
#        [ 30,  80, 130, 180]])

# %%
b.cumsum(axis=1)
# Out:
# array([[  2,  14,  36,  68],
#        [  4,  18,  42,  76],
#        [  6,  22,  48,  84],
#        [  8,  26,  54,  92],
#        [ 10,  30,  60, 100]])

# %% [markdown]
# #### Max()

# %%
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
b.max()
# Out:
# np.int64(40)

# %%
b.max(axis=0)
# Out:
# array([10, 20, 30, 40])

# %%
b.max(axis=1)
# Out:
# array([32, 34, 36, 38, 40])

# %% [markdown]
# #### Min()

# %%
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
b.min()
# Out:
# np.int64(2)

# %%
b.min(axis=0)
# Out:
# array([ 2, 12, 22, 32])

# %%
b.min(axis=1)
# Out:
# array([ 2,  4,  6,  8, 10])

# %% [markdown]
# #### Mean(),Median()

# %%
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
b.mean()
# Out:
# np.float64(21.0)

# %%
b.mean(axis=0)
# Out:
# array([ 6., 16., 26., 36.])

# %%
b.mean(axis=1)
# Out:
# array([17., 19., 21., 23., 25.])

# %%
np.median(b)
# Out:
# np.float64(21.0)

# %%
np.median(b,axis=0)
# Out:
# array([ 6., 16., 26., 36.])

# %%
np.median(b,axis=1)
# Out:
# array([17., 19., 21., 23., 25.])

# %% [markdown]
# #### Standard Deviation - np.std(array_name)

# %%
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
np.std(b)
# Out:
# np.float64(11.532562594670797)

# %%
np.std(b,axis=0)
# Out:
# array([2.82842712, 2.82842712, 2.82842712, 2.82842712])

# %%
np.std(b,axis=1)
# Out:
# array([11.18033989, 11.18033989, 11.18033989, 11.18033989, 11.18033989])

# %% [markdown]
# #### Variance- np.var(array_name)

# %%
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
np.var(b)
# Out:
# np.float64(133.0)

# %% [markdown]
# #### Percentile()

# %%
np.percentile(b,10)
# Out:
# np.float64(5.800000000000001)

# %%
np.percentile(b,5)
# Out:
# np.float64(3.9000000000000004)

# %%
np.percentile(b,100)
# Out:
# np.float64(40.0)

# %% [markdown]
# #### Square Root - np.sqrt()

# %%
b
# Out:
# array([[ 2, 12, 22, 32],
#        [ 4, 14, 24, 34],
#        [ 6, 16, 26, 36],
#        [ 8, 18, 28, 38],
#        [10, 20, 30, 40]])

# %%
np.sqrt(b)
# Out:
# array([[1.41421356, 3.46410162, 4.69041576, 5.65685425],
#        [2.        , 3.74165739, 4.89897949, 5.83095189],
#        [2.44948974, 4.        , 5.09901951, 6.        ],
#        [2.82842712, 4.24264069, 5.29150262, 6.164414  ],
#        [3.16227766, 4.47213595, 5.47722558, 6.32455532]])

# %% [markdown]
# #### exponential e-np.exp(arr)

# %%
np.exp(b)
# Out:
# array([[7.38905610e+00, 1.62754791e+05, 3.58491285e+09, 7.89629602e+13],
#        [5.45981500e+01, 1.20260428e+06, 2.64891221e+10, 5.83461743e+14],
#        [4.03428793e+02, 8.88611052e+06, 1.95729609e+11, 4.31123155e+15],
#        [2.98095799e+03, 6.56599691e+07, 1.44625706e+12, 3.18559318e+16],
#        [2.20264658e+04, 4.85165195e+08, 1.06864746e+13, 2.35385267e+17]])

# %% [markdown]
# #### Natural Algorithm - np.log(arr)

# %%
np.log(b)
# Out:
# array([[0.69314718, 2.48490665, 3.09104245, 3.4657359 ],
#        [1.38629436, 2.63905733, 3.17805383, 3.52636052],
#        [1.79175947, 2.77258872, 3.25809654, 3.58351894],
#        [2.07944154, 2.89037176, 3.33220451, 3.63758616],
#        [2.30258509, 2.99573227, 3.40119738, 3.68887945]])

# %% [markdown]
# #### Absolute Values - np.abs(arr)

# %%
a=np.array([-1,-2,-3,-4,-5])
a
# Out:
# array([-1, -2, -3, -4, -5])

# %%
np.abs(a)
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# #### Rounding Up - np.ceil(arr) , Down - np.floor(arr)

# %%
arr=np.log(b)

# %%
arr
# Out:
# array([[0.69314718, 2.48490665, 3.09104245, 3.4657359 ],
#        [1.38629436, 2.63905733, 3.17805383, 3.52636052],
#        [1.79175947, 2.77258872, 3.25809654, 3.58351894],
#        [2.07944154, 2.89037176, 3.33220451, 3.63758616],
#        [2.30258509, 2.99573227, 3.40119738, 3.68887945]])

# %%
np.ceil(arr)
# Out:
# array([[1., 3., 4., 4.],
#        [2., 3., 4., 4.],
#        [2., 3., 4., 4.],
#        [3., 3., 4., 4.],
#        [3., 3., 4., 4.]])

# %%
np.floor(arr)
# Out:
# array([[0., 2., 3., 3.],
#        [1., 2., 3., 3.],
#        [1., 2., 3., 3.],
#        [2., 2., 3., 3.],
#        [2., 2., 3., 3.]])

# %% [markdown]
# ### Exercise

# %%
# create an array of data
data=np.arange(50)
# calculate the mean
print("Mean : ",np.mean(data))
# calculate the median
print("Median : ",np.median(data))
# calculate the variance
print("Variance : ",np.var(data))
# calculate the standard deviation
print("Standard Deviation : ",np.std(data))
# calculate the minimum and maximum values
print("Maximum : ",np.max(data))
print("Minimum : ",np.min(data))
# Out:
# Mean :  24.5
# Median :  24.5
# Variance :  208.25
# Standard Deviation :  14.430869689661812
# Maximum :  49
# Minimum :  0
